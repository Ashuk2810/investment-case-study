# %%
import pandas as pd

# %% [markdown]
# 1. Reading the Rounds2, companies.txt files.

# %%
companies=pd.read_csv('companies.txt',sep='\t')
companies
# Out:
#                                                permalink  \
# 0                                    /Organization/-Fame
# 1                                 /Organization/-Qounter
# 2                    /Organization/-The-One-Of-Them-Inc-
# 3                                  /Organization/0-6-Com
# 4                         /Organization/004-Technologies
# ...                                                  ...
# 66363  /Organization/Zznode-Science-And-Technology-Co...
# 66364                          /Organization/Zzzzapp-Com
# 66365                               /Organization/ÃEron
# 66366                             /Organization/Ã”Asys-2
# 66367  /Organization/Ä°Novatiff-Reklam-Ve-Tanä±Tä±M-H...
#
#                                                 name  \
# 0                                              #fame
# 1                                           :Qounter
# 2                             (THE) ONE of THEM,Inc.
# 3                                            0-6.com
# ...

# %%
rounds2=pd.read_csv('rounds.csv')
rounds2
# Out:
#                                         company_permalink  \
# 0                                     /organization/-fame
# 1                                  /ORGANIZATION/-QOUNTER
# 2                                  /organization/-qounter
# 3                     /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                                   /organization/0-6-com
# ...                                                   ...
# 114944                          /organization/zzzzapp-com
# 114945                          /ORGANIZATION/ZZZZAPP-COM
# 114946                                /organization/�eron
# 114947                              /ORGANIZATION/ÔASYS-2
# 114948  /organization/�novatiff-reklam-ve-tan�t�m-hizm...
#
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1       /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# ...

# %%
rounds2['company_permalink'] =rounds2['company_permalink'].str.lower()

# %% [markdown]
# 2. How many unique companies are present in rounds2?

# %%
temp1=pd.DataFrame(rounds2.company_permalink.unique())
temp1
# Out:
#                                                        0
# 0                                    /organization/-fame
# 1                                 /organization/-qounter
# 2                    /organization/-the-one-of-them-inc-
# 3                                  /organization/0-6-com
# 4                         /organization/004-technologies
# ...                                                  ...
# 66368  /organization/zznode-science-and-technology-co...
# 66369                          /organization/zzzzapp-com
# 66370                                /organization/�eron
# 66371                              /organization/ôasys-2
# 66372  /organization/�novatiff-reklam-ve-tan�t�m-hizm...
#
# [66373 rows x 1 columns]

# %%
companies['permalink'] = companies['permalink'].str.lower()

# %% [markdown]
# 3. How many unique companies are present in the companies file?

# %%
temp2=pd.DataFrame(companies.permalink.unique())
temp2
# Out:
#                                                        0
# 0                                    /organization/-fame
# 1                                 /organization/-qounter
# 2                    /organization/-the-one-of-them-inc-
# 3                                  /organization/0-6-com
# 4                         /organization/004-technologies
# ...                                                  ...
# 66363  /organization/zznode-science-and-technology-co...
# 66364                          /organization/zzzzapp-com
# 66365                               /organization/ãeron
# 66366                             /organization/ã”asys-2
# 66367  /organization/ä°novatiff-reklam-ve-tanä±tä±m-h...
#
# [66368 rows x 1 columns]

# %% [markdown]
# 4.Write the code to convert companies[‘permalink’] and Round2[‘company_permalink’] columns
# to uppercase.

# %%
rounds2['company_permalink'] =rounds2['company_permalink'].str.upper()
rounds2
# Out:
#                                         company_permalink  \
# 0                                     /ORGANIZATION/-FAME
# 1                                  /ORGANIZATION/-QOUNTER
# 2                                  /ORGANIZATION/-QOUNTER
# 3                     /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                                   /ORGANIZATION/0-6-COM
# ...                                                   ...
# 114944                          /ORGANIZATION/ZZZZAPP-COM
# 114945                          /ORGANIZATION/ZZZZAPP-COM
# 114946                                /ORGANIZATION/�ERON
# 114947                              /ORGANIZATION/ÔASYS-2
# 114948  /ORGANIZATION/�NOVATIFF-REKLAM-VE-TAN�T�M-HIZM...
#
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1       /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# ...

# %%
companies['permalink'] = companies['permalink'].str.upper()
companies
# Out:
#                                                permalink  \
# 0                                    /ORGANIZATION/-FAME
# 1                                 /ORGANIZATION/-QOUNTER
# 2                    /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 3                                  /ORGANIZATION/0-6-COM
# 4                         /ORGANIZATION/004-TECHNOLOGIES
# ...                                                  ...
# 66363  /ORGANIZATION/ZZNODE-SCIENCE-AND-TECHNOLOGY-CO...
# 66364                          /ORGANIZATION/ZZZZAPP-COM
# 66365                               /ORGANIZATION/ÃERON
# 66366                             /ORGANIZATION/Ã”ASYS-2
# 66367  /ORGANIZATION/Ä°NOVATIFF-REKLAM-VE-TANÄ±TÄ±M-H...
#
#                                                 name  \
# 0                                              #fame
# 1                                           :Qounter
# 2                             (THE) ONE of THEM,Inc.
# 3                                            0-6.com
# ...

# %% [markdown]
#  5. Are there any companies in the rounds2 file which are not present in companies.txt ?

# %%
set(companies['permalink'].unique()).difference(set(rounds2['company_permalink'].unique()))
# Out:
# {'/ORGANIZATION/10Â°NORTH',
#  '/ORGANIZATION/51WOFANG-Æ— Å¿§Æˆ‘Æˆ¿',
#  '/ORGANIZATION/ADSLINKEDÂ„¢',
#  '/ORGANIZATION/AESTHETIC-EVERYTHINGÂ®-SOCIAL-NETWORK',
#  '/ORGANIZATION/AFFLUENT-ATTACHÃ©-CLUB-2',
#  '/ORGANIZATION/ALLGÃ¤U-OUTLET',
#  '/ORGANIZATION/ASIANSBOOKÂ„¢',
#  '/ORGANIZATION/ATÃ¶LYE-GRI',
#  '/ORGANIZATION/AXÃ¨GAZ',
#  '/ORGANIZATION/BORÃ©AL-BIKES-INCORPORATED',
#  '/ORGANIZATION/BRASIL-OZÃ´NIO',
#  '/ORGANIZATION/BRICOPRIVÃ©-COM',
#  '/ORGANIZATION/BRÄ\x81V',
#  '/ORGANIZATION/BÃ¶HNER-EH-GMBH',
#  '/ORGANIZATION/CANAL-DA-PEÃ§A',
#  '/ORGANIZATION/CAPPTÃº',
#  '/ORGANIZATION/CONTRATO-RÃ¡PIDO',
#  '/ORGANIZATION/COPÃ©-ACTIVE-LTD',
#  '/ORGANIZATION/CRÃ¨ME-CISEAUX',
#  '/ORGANIZATION/DESAFÃ\xadO-TÃ¡CTICO',
#  '/ORGANIZATION/E-CÃŠBICA',
#  '/ORGANIZATION/ENERGYSTONE-GAMES-Ç\x81ΜÇŸ³Æ¸¸Æˆ\x8f',
#  '/ORGANIZATION/ETOOL-IOÂ”',
#  '/ORGANIZATION/FREEMÅ\x8d',
#  '/ORGANIZATION/FRÃ©QUENTIEL',
#  '/ORGANIZATION/GESTO-SAÃºDE-E-TECNOLOGIA-3',
# ...

# %% [markdown]
# 6. Merge the two data frames so that all variables (columns) in the company's frame are added
# to the rounds2 data frame. Name the merged frame master_dataframe. How many observations
# are present in master_frame ?

# %%
master_frame = pd.merge(rounds2,companies, how ='left', left_on ='company_permalink', right_on ='permalink')
master_frame
# Out:
#                                         company_permalink  \
# 0                                     /ORGANIZATION/-FAME
# 1                                  /ORGANIZATION/-QOUNTER
# 2                                  /ORGANIZATION/-QOUNTER
# 3                     /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                                   /ORGANIZATION/0-6-COM
# ...                                                   ...
# 114944                          /ORGANIZATION/ZZZZAPP-COM
# 114945                          /ORGANIZATION/ZZZZAPP-COM
# 114946                                /ORGANIZATION/�ERON
# 114947                              /ORGANIZATION/ÔASYS-2
# 114948  /ORGANIZATION/�NOVATIFF-REKLAM-VE-TAN�T�M-HIZM...
#
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1       /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# ...

# %% [markdown]
# How many observations
# are present in master_frame ?

# %%
print("number of observations present in master_frame- ",master_frame.shape[0])
# Out:
# number of observations present in master_frame-  114949

# %% [markdown]
# 7. Write the code to drop the redundant column ‘'company_permalink' from the
# master_dataframe.

# %%
master_frame.drop(columns='company_permalink',inplace=True)
master_frame
# Out:
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1       /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2       /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3       /funding-round/650b8f704416801069bb178a1418776b            venture
# 4       /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
# ...                                                 ...                ...
# 114944  /funding-round/8f6d25b8ee4199e586484d817bceda05   convertible_note
# 114945  /funding-round/ff1aa06ed5da186c84f101549035d4ae               seed
# 114946  /funding-round/59f4dce44723b794f21ded3daed6e4fe            venture
# 114947  /funding-round/35f09d0794651719b02bbfd859ba9ff5               seed
# 114948  /funding-round/af942869878d2cd788ef5189b435ebc4              grant
#
#        funding_round_code   funded_at  raised_amount_usd  \
# ...

# %% [markdown]
# 8. Write the code to find the percentage missing value (column-wise) in master_dataframe. Drop
# unnecessary columns.

# %%
percent_missing = master_frame.isnull().sum() * 100 / len(master_frame)
missing_value_df = pd.DataFrame({'percent_missing (%)': percent_missing})

missing_value_df.sort_values('percent_missing (%)',ascending=False)
# Out:
#                          percent_missing (%)
# funding_round_code                 72.909725
# founded_at                         17.887933
# raised_amount_usd                  17.390321
# state_code                          9.549452
# region                              8.873500
# city                                8.870891
# country_code                        7.578143
# homepage_url                        5.393696
# category_list                       3.010900
# name                                0.065246
# permalink                           0.064376
# status                              0.064376
# funding_round_permalink             0.000000
# funding_round_type                  0.000000
# funded_at                           0.000000

# %% [markdown]
# 9. Create a pivot table to compare the mean and median values for ‘raised_amount_usd’ and
# ‘funding_round_type’ across different funding round categories..

# %%
table=pd.pivot_table(master_frame,index=['funding_round_type','status'],values='raised_amount_usd',aggfunc=['mean','median'])
table
# Out:
#                                              mean            median
#                                 raised_amount_usd raised_amount_usd
# funding_round_type    status
# angel                 acquired       1.087982e+06          665750.0
#                       closed         7.940892e+05          330000.0
#                       ipo            1.689660e+06          625000.0
#                       operating      9.680663e+05          400000.0
# convertible_note      acquired       1.083682e+06          500000.0
#                       closed         9.633743e+05          242500.0
#                       ipo            1.866318e+07         2778771.0
#                       operating      1.154338e+06          250000.0
# debt_financing        acquired       1.477531e+07         2000000.0
#                       closed         6.368645e+06         1000000.0
#                       ipo            1.083672e+08         4702815.0
# ...

# %% [markdown]
# 10. Filter the master_dataframe on ‘raised_amount_usd’ such as ‘raised_amount_usd’ lie
# between 4 Millions to 15 Millions.

# %%
df_for_raised_amount_usd_between_4m_15m=master_frame[master_frame['raised_amount_usd'].between(4000000,15000000)]
df_for_raised_amount_usd_between_4m_15m
# Out:
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 12      /funding-round/e1cfcbe1bdf4c70277c5f29a3482f24e            venture
# 21      /funding-round/11c228f58831bc7ed337ef69ecc560c2     private_equity
# 22      /funding-round/b952cbaf401f310927430c97b68162ea            venture
# 28      /funding-round/0faccbbcc5818dc5326469f13f5a8ac8            venture
# ...                                                 ...                ...
# 114921  /funding-round/85443f5438bfd50104b9591eabc95c94              grant
# 114922  /funding-round/b4fce7f8a13267353d57db09099800e8            venture
# 114930  /funding-round/c05aab2155e390066d51c6852ff61464              grant
# 114931  /funding-round/e949f077c943db197f20e43c2eb8d0e6            venture
# 114936  /funding-round/7ea37c0ff4132b084832039a9380d34e            venture
#
#        funding_round_code   funded_at  raised_amount_usd  \
# ...

# %% [markdown]
# 11.Identify the top 9 countries in terms of highest investment in ‘venture’ fund type.

# %%
loc= master_frame.loc[master_frame.funding_round_type=="venture"]
loc1=loc.groupby(by='country_code')['raised_amount_usd'].sum().to_frame()
loc1.sort_values('raised_amount_usd',ascending=False).head(9)
# Out:
#               raised_amount_usd
# country_code
# USA                4.225108e+11
# CHN                3.983542e+10
# GBR                2.024563e+10
# IND                1.439186e+10
# CAN                9.583332e+09
# FRA                7.241142e+09
# ISR                6.907515e+09
# DEU                6.345560e+09
# JPN                3.363677e+09

# %% [markdown]
# 12. Create the ‘main_category’ column by extracting the main sector using the column
# ‘category_list’.
# Hint - Use the Lambda function or string function

# %%
df_split = master_frame.category_list.str.split(pat='|',expand=True)
master_frame['main_category'] =df_split.loc[:,0]
master_frame
# Out:
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1       /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2       /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3       /funding-round/650b8f704416801069bb178a1418776b            venture
# 4       /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
# ...                                                 ...                ...
# 114944  /funding-round/8f6d25b8ee4199e586484d817bceda05   convertible_note
# 114945  /funding-round/ff1aa06ed5da186c84f101549035d4ae               seed
# 114946  /funding-round/59f4dce44723b794f21ded3daed6e4fe            venture
# 114947  /funding-round/35f09d0794651719b02bbfd859ba9ff5               seed
# 114948  /funding-round/af942869878d2cd788ef5189b435ebc4              grant
#
#        funding_round_code   funded_at  raised_amount_usd  \
# ...

# %% [markdown]
# 13. Using the user defined function convert the ‘rasied_amount_used’ column into a categorical
# column as follow
# a) If the amount is less than 5 Millions then recode as TypeA.
# b) If the amount is greater than 5 Millions and less than 7 Millions then recode as TypeB.
# c) If the amount is greater than 7 Millions then recode as TypeC

# %%
list_of=[]
def category(p):
    A="Type A"
    B="Type B"
    C="Type C"
    for i in p:
        if i < 5000000:
            list_of.append(A)
        elif i >=5000000 and i < 7000000:
            list_of.append(B)
        else:
            list_of.append(C)
category(master_frame.raised_amount_usd)

# %%
master_frame['cat']=list_of
master_frame
# Out:
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1       /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2       /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3       /funding-round/650b8f704416801069bb178a1418776b            venture
# 4       /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
# ...                                                 ...                ...
# 114944  /funding-round/8f6d25b8ee4199e586484d817bceda05   convertible_note
# 114945  /funding-round/ff1aa06ed5da186c84f101549035d4ae               seed
# 114946  /funding-round/59f4dce44723b794f21ded3daed6e4fe            venture
# 114947  /funding-round/35f09d0794651719b02bbfd859ba9ff5               seed
# 114948  /funding-round/af942869878d2cd788ef5189b435ebc4              grant
#
#        funding_round_code   funded_at  raised_amount_usd  \
# ...

# %%
m1=master_frame.groupby(by='funding_round_type')['raised_amount_usd'].sum().to_frame()
m4=m1.sort_values('raised_amount_usd',ascending=False).head(10)
m4
m2=master_frame.groupby(by='country_code')['raised_amount_usd'].sum().to_frame()
m3=m2.sort_values('raised_amount_usd',ascending=False).head(10)
m3
# Out:
#               raised_amount_usd
# country_code
# USA                6.694814e+11
# CHN                7.570357e+10
# GBR                3.276689e+10
# IND                2.768634e+10
# CAN                1.842468e+10
# RUS                1.127912e+10
# DEU                1.001634e+10
# ISR                9.713885e+09
# FRA                9.038567e+09
# NLD                5.966633e+09

# %% [markdown]
# As it can be seen from the above two codes, these were the top 10 investment types and the top 10 countries.
# Since venture type is having the most investment and in Q.11, USA is having the highest investment in venture type,
# it will be best to invest in Venture types in USA as it is the best country and most suitable investment type on the basis
# of countries where most investors were investing
